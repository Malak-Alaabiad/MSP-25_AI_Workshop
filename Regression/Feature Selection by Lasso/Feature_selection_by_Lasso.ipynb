# %% [markdown]
# # Feature selection by Lasso Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso

# %%
boston = pd.read_csv('HousingData.csv')
#boston.head()
boston.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99    NaN  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
#boston.isna()   # true or false for all column
#boston['ZN'].isnull().values.any()   # true or false for one column
#boston['PTRATIO'].isnull().sum()  # بتعد في كام قيمه مفقوده
#boston.isnull().values.any()
#boston.isnull().tail()
#boston.notnull().tail()
boston.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
boston.shape
# Out:
# (506, 14)

# %%
fill_nan = boston['CRIM'].fillna(value=0,inplace = True)
fill_nan = boston['ZN'].fillna(value=0 ,inplace = True)
fill_nan = boston['INDUS'].fillna(value= 0,inplace = True)
fill_nan = boston['CHAS'].fillna(value= 0,inplace = True)
fill_nan = boston['AGE'].fillna(value= 0,inplace = True)
fill_nan = boston['LSTAT'].fillna(value= 0 ,inplace = True)
# Out:
# <ipython-input-5-294f7190231b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fill_nan = boston['CRIM'].fillna(value=0,inplace = True)
# <ipython-input-5-294f7190231b>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fill_nan = boston['ZN'].fillna(value=0 ,inplace = True)
# <ipython-input-5-294f7190231b>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fill_nan = boston['INDUS'].fillna(value= 0,inplace = True)
# <ipython-input-5-294f7190231b>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fill_nan = boston['CHAS'].fillna(value= 0,inplace = True)
# <ipython-input-5-294f7190231b>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fill_nan = boston['AGE'].fillna(value= 0,inplace = True)
# <ipython-input-5-294f7190231b>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fill_nan = boston['LSTAT'].fillna(value= 0 ,inplace = True)

# %%
X = boston.drop('MEDV', axis = 1).values
y = boston['MEDV'].values

# %%
names = boston.columns.drop('MEDV')
print(names)
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
len(names)
# Out:
# 13

# %%
lasso = Lasso(alpha = 0.1)
lasso.fit(X,y)
# Out:
# Lasso(alpha=0.1)

# %%
coeff = lasso.coef_
coeff
# Out:
# array([-0.10827023,  0.0484652 , -0.05798282,  1.41597717, -0.        ,
#         4.26006424, -0.02141141, -1.10335645,  0.24850677, -0.01418573,
#        -0.79946215,  0.01034894, -0.43173415])

# %%
plt.plot(range(len(names)),coeff)
plt.xticks(range(len(names)),names,rotation = 60)  # حجزت 13 مكان ل 13 اسم دوران الكلمه 60
plt.ylabel('coffecients')
plt.show()

# %%
import seaborn as sns
sns.pairplot(boston)

# %%
plt.scatter(boston["RM"],boston["MEDV"])
